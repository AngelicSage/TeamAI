# %% [markdown]
# # Loading dataset

# %% [markdown]
# link to data set: https://www.kaggle.com/competitions/ai-mathematical-olympiad-prize/data

# %%
# prompt: write code for me to input a file containing the data

from google.colab import files

uploaded = files.upload()

# The uploaded file is available as a dictionary with the filename as the key.
# You can access the contents of the file using the filename as the index.
data = uploaded['olympiad.zip']

# Now you can process the data as needed.
# For example, you can print the first few lines of the data:
print(data[:5])
# Out:
#      <input type="file" id="files-70100fed-57c9-475b-89d6-c0c1e2fb157a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70100fed-57c9-475b-89d6-c0c1e2fb157a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
zip_path = '/content/olympiad.zip'  # Or adjust the path if it's located elsewhere

# Unzipping the dataset
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/dataset')  # You can specify your path here
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-10-814941121f59> in <cell line: 6>()
#       4 zip_path = '/content/olympiad.zip'  # Or adjust the path if it's located elsewhere
#       5
# ----> 6 os.makedirs('/content/dataset')
#       7 # Unzipping the dataset
#       8 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#
# /usr/lib/python3.10/os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: '/content/dataset'

# %%
import pandas as pd

# Load the training data
train_data = pd.read_csv('/content/dataset/test.csv')

# Load the test data
test_data = pd.read_csv('/content/dataset/train.csv')

# Now you can view the first few rows of each to confirm they're loaded correctly
train_data.head()
test_data.head()
# Out:
#        id                                            problem  answer
# 0  229ee8  Let $k, l > 0$ be parameters. The parabola $y ...      52
# 1  246d26  Each of the three-digits numbers $111$ to $999...     250
# 2  2fc4ad  Let the `sparkle' operation on positive intege...     702
# 3  430b63  What is the minimum value of $5x^2+5y^2-8xy$ w...     800
# 4  5277ed  There exists a unique increasing geometric seq...     211
